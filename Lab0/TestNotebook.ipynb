# %%
dane = [23, 45, 67, 89, 12]
for wartosc in dane: print(f"Wartość: {wartosc}")
# Out:
# Wartość: 23
# Wartość: 45
# Wartość: 67
# Wartość: 89
# Wartość: 12

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Wczytanie danych
df = pd.read_csv('dane.csv')
# Statystyki opisowe
print(df.describe())
# Filtrowanie
filtered = df[df['wiek'] > 25]
# Grupowanie i agregacja
grouped = df.groupby('kategoria')['wartosc'].mean()
# Wizualizacja
grouped.plot(kind='bar')
plt.show()
# Out:
#              id       wiek     wartosc
# count  10.00000  10.000000   10.000000
# mean    5.50000  31.100000  195.480000
# std     3.02765   5.466057   30.292346
# min     1.00000  24.000000  150.500000
# 25%     3.25000  27.250000  172.825000
# 50%     5.50000  30.000000  195.600000
# 75%     7.75000  34.250000  217.775000
# max    10.00000  41.000000  240.600000
